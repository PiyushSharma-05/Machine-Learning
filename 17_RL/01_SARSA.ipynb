# %%
pip install gymnasium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "gymnasium[toy-text]"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gymnasium as gym
import numpy as np
import random

# %%
env = gym.make("CliffWalking-v1")
print(env.observation_space.n) # states
print(env.action_space.n) # actions
starting_state, _ = env.reset() 
print(starting_state)
# Out:
# 48
# 4
# 36

# %% [markdown]
# # SARSA

# %%
gamma = 0.99
alpha = 0.5
epsilon = 0.1
episodes = 500

Q = np.zeros((48, 4))

# %%
def epsilon_greedy(state):
    if random.random() < epsilon:
        return env.action_space.sample()
    else:
        return np.argmax(Q[state])

for episode in range(episodes):
    env = gym.make("CliffWalking-v1")
    done = False
    state, _ = env.reset()
    action = epsilon_greedy(state)

    total_reward = 0
    episode_len = 0

    while not done:
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        next_action = epsilon_greedy(next_state)

        #SARSA Update
        Q[state, action] += alpha * (reward + gamma * (Q[next_state, next_action] - Q[state, action]))
        state = next_state
        action = next_action

        total_reward += reward
        episode_len += 1

    print(f'episode: {episode+1}/500 has total reward{total_reward} and episode len={episode_len}')
    env.close()
# Out:
# episode: 1/500 has total reward-1150 and episode len=358
# episode: 2/500 has total reward-1123 and episode len=430
# episode: 3/500 has total reward-97 and episode len=97
# episode: 4/500 has total reward-102 and episode len=102
# episode: 5/500 has total reward-41 and episode len=41
# episode: 6/500 has total reward-217 and episode len=118
# episode: 7/500 has total reward-34 and episode len=34
# episode: 8/500 has total reward-76 and episode len=76
# episode: 9/500 has total reward-76 and episode len=76
# episode: 10/500 has total reward-59 and episode len=59
# episode: 11/500 has total reward-186 and episode len=87
# episode: 12/500 has total reward-299 and episode len=101
# episode: 13/500 has total reward-170 and episode len=71
# episode: 14/500 has total reward-33 and episode len=33
# episode: 15/500 has total reward-33 and episode len=33
# episode: 16/500 has total reward-174 and episode len=75
# episode: 17/500 has total reward-31 and episode len=31
# ...

# %%
# What our model learnt from this training

env = gym.make("CliffWalking-v1", render_mode="human")
state, _ = env.reset()
done = False

total_reward = 0
episode_len = 0

while not done:
    action = np.argmax(Q[state])
    state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    total_reward += reward
    episode_len += 1

print(f'total reward: {total_reward} and episode length: {episode_len}')
env.close()
# Out:
# total reward: -17 and episode length: 17
